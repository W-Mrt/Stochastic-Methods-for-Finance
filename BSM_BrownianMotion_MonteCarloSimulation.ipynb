# %% [markdown]
# # Black Scholes Merton Model
# **Based on Geometric Brownian Motion Simulation**

# %% [markdown]
# At the moment of pricing options, the indisputable benchmark is the Black Scholes Merton (BSM) model presented in 1973 at the *Journal of Political Economy*. In the paper, they derive a mathematical formula to price options based on a stock that follows a Geometric Brownian Motion.
#
# In this work, we will replicate that valuation, but instead of deriving the value of the option mathematically, we are going to generate 100 paths through Monte Carlo simulation.

# %% [markdown]
# ## Preparing Environment

# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import math
import matplotlib.pyplot as plt

# %% [markdown]
# ### Graph Formating

# %%
plt.style.use('seaborn')
plt.rcParams['font.family'] = 'serif'
# %matplotlib inline

SMALL_SIZE = 14
MEDIUM_SIZE = 16
BIGGER_SIZE = 18

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

# %% [markdown]
# ## Market Variables

# %% [markdown]
# The BSM model describes the market with one risky asset called the stock ($S$) and one riskless asset known as the bond (represented as a short term interest rate $r$).
#
# For this analysis, the environment that we are defining consist in an initial stock value $S_{0} = 100$  and a constant interest rate $r=0.10$. The volatility of the stock is represented by $\sigma = 0.2$ and the time period for the simulation is one year $t=1$.
#
# N different paths, M days in a year.

# %%
S0 = 100.
r = 0.01
sigma = 0.20
T = 1
K = 99
N = 10000

# %%
M = 252
dt = T / M
dt
# Out:
# 0.003968253968253968

# %% [markdown]
# ## Generate the Geometric Brownian Motion Simulation

# %% [markdown]
# To create the different paths, we begin by utilizing the function `np.random.standard_normal` that draw  $(M+1)\times N$ samples from a standard Normal distribution.
# To ensure that the mean is 0 and the standard deviation is 1 we adjust the generated values with a technique called moment matching.

# %%
z = np.random.standard_normal((M+1,N))
z -= z.mean()
z /= z.std()

# %% [markdown]
# Once we have the normally distributed sample matrix, we can proceed to calculate the differents paths utilizing the difference equation of the Geometric Brownian Motion stochastic process.

# %% [markdown]
# $$S_t = S_{t - \Delta t} \cdot \exp \left(\left(r - \frac{\sigma^2}{2} \right)\Delta t + \sigma \sqrt{\Delta t} z \right)$$

# %% [markdown]
# We substitute the values of the equation with the previously defined variables and replace the $z$ term with the previously generated normal matrix.

# %%
S = np.zeros((M+1,N))
S[0] = S0

# %%
for i in range(1,M+1):
    S[i] = S[i-1] * np.exp((r - 0.5 * sigma ** 2) * dt + sigma * math.sqrt(dt) * z[i])

# %% [markdown]
# In the chart, we can see a representation of the behaviour of the first 100 paths. Even though all start with a value of 100, the stock's final value varies with the previously mentioned volatility of 20%.

# %%
plt.figure(figsize=(20, 12))
plt.title('100 Simulated Stocks Paths',fontweight="bold", pad=20)
plt.xlabel('Steps')
plt.ylabel('Price')
plt.plot(S[:, :50]);
# plt.savefig('paths.png', facecolor='None')

# %% [markdown]
# To have a quick snapshot of the 100 final values, we represent them with a histogram. As we can see, the distribution is leaned towards a final price over 100, since the generated Brownian motion has a positive drift of the size of $r=0.10$.

# %%
plt.figure(figsize=(10,6))
plt.hist(S[-1], bins=45)
plt.title('Histogram of Final Value of the Stock' ,fontweight="bold", pad=20);
plt.axvline(S[-1].mean(), c='b');
# plt.savefig('histogram.png', facecolor='None')

# %% [markdown]
# We can calculate the mathematical expected value with the following equation:
# $$S_{T} = S_{0}  exp^{r  T}$$

# %%
S0 * math.exp(r * T)
# Out:
# 101.00501670841679

# %% [markdown]
# If we observe the mean of the last value of the 100 paths, we derive a similar value. This means that the simulation of the stock is a good representation of its theoretical intrinsic value.

# %%
S[-1].mean()
# Out:
# 101.02739665592443

# %% [markdown]
# We can visually explore the convergence of the simulated price to the theoretical value plotting the evolution of the mean for every new sampled observation.

# %%
S_sim = np.zeros(N)
for x in range(0,N):
    S_sim[x] = S[-1][0:x+1].mean()
    
plt.figure(figsize=(10, 6))
plt.title('Convergence Into Mathematical Value',fontweight="bold", pad=20)
plt.xlabel('Iterations')
plt.ylabel('Final Price')
plt.plot(S_sim);
# plt.savefig('convergence.png', facecolor='None')

# %% [markdown]
# ## European Call Pricing

# %% [markdown]
# After we generated the risky asset paths, we proceed to do the same for the contingent option.  For this example, we valued a European call option with a strike price of 99 ($K=99$).

# %%
K = 99.

# %% [markdown]
# To calculate the fair value of the option (at moment $T$), we did a vector operation that finds the max value between $0$ and the Stock value minus the strike price. $V_{T}=max(0,S_{T}-K)$

# %%
V = np.maximum(0, S[-1] - K)
European_Call = V.mean()
print("European Call")
print(European_Call)
# Out:
# European Call
# 9.065812423651384

# %% [markdown]
# We can represent the 100 values of the call option by plotting them in a histogram. As we can see, many observations are 0 because, in those scenarios, the option matures out of the money ($K>S_{T}$).

# %%
plt.figure(figsize=(10,6))
plt.hist(math.exp(-r * T) * V, bins=45)
plt.title('Histogram of Value of the European Call Option',fontweight="bold", pad=20)
plt.axvline(math.exp(-r * T) * V.mean(), c='b');
# plt.savefig('call.png', facecolor='None')

# %% [markdown]
# To derive the simulated fair value ($FV_{0}$) of the Call Option, we need to compute the mean of the final value that we calculated in the previous step ($FV_{T}$) and discount it back to today.

# %%
FV = math.exp(-r * T) * V.mean()
print("European Call simulated")
print(FV)
# Out:
# European Call simulated
# 8.975606082837196

# %% [markdown]
# To conclude, we derived an alternative to the traditional BSM model. Nevertheless, given the model's assumptions, it is more accurate to calculate the option theoretically than in a simulated fashion. However, we can improve the simulation to be closer to the real market environment than the model environment (for example: adding jumps, modelling the volatility or interest rate).

# %% [markdown]
# ## European Put Pricing

# %%
V = np.maximum(0, K - S[-1])
European_Put = V.mean()
print("European Put")
print(European_Put)
# Out:
# European Put
# 7.03841576772696

# %%
plt.figure(figsize=(10,6))
plt.hist(math.exp(-r * T) * V, bins=45)
plt.title('Histogram of Value of the European Put Option',fontweight="bold", pad=20)
plt.axvline(math.exp(-r * T) * V.mean(), c='b');
# plt.savefig('call.png', facecolor='None')

# %%
FV = math.exp(-r * T) * V.mean()
print("European Put simulated")
print(FV)
# Out:
# European Put simulated
# 6.9683823606956

# %% [markdown]
# ## References

# %% [markdown]
# "Derivatives Analytics with Python" by Yves Hilpisch.
